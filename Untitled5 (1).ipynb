# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # New Section

# %%
cd drive/MyDrive/ml
# Out:
# /content/drive/MyDrive/ml

# %%
import string
import numpy as np
from PIL import Image
import os
from pickle import dump, load
import numpy as np
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.applications.xception import Xception, preprocess_input
from keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical, get_file
from keras.layers import add
from keras.models import Model, load_model
from keras.layers import Input, Dense, LSTM, Embedding, Dropout

# %%
from tqdm.notebook import tqdm  # Import tqdm correctly
tqdm.pandas()  # Enable progress_apply for Pandas

# %%
# Loading a text file into memory
def load_doc(filename):
    # Opening the file as read only
    file = open(filename, 'r')
    text = file.read()
    file.close()
    return text

# %%
# get all imgs with their captions
def all_img_captions(filename):
    file = load_doc(filename)
    captions = file.split('\n')
    descriptions ={}
    for caption in captions[:-1]:
        img, caption = caption.split('\t')
        if img[:-2] not in descriptions:
            descriptions[img[:-2]] = [ caption ]
        else:
            descriptions[img[:-2]].append(caption)
    return descriptions

# %%
#Data cleaning- lower casing, removing puntuations and words containing numbers
def cleaning_text(captions):
    table = str.maketrans('','',string.punctuation)
    for img,caps in captions.items():
        for i,img_caption in enumerate(caps):

            img_caption.replace("-"," ")
            desc = img_caption.split()

            #converts to lowercase
            desc = [word.lower() for word in desc]
            #remove punctuation from each token
            desc = [word.translate(table) for word in desc]
            #remove hanging 's and a
            desc = [word for word in desc if(len(word)>1)]
            #remove tokens with numbers in them
            desc = [word for word in desc if(word.isalpha())]
            #convert back to string

            img_caption = ' '.join(desc)
            captions[img][i]= img_caption
    return captions

# %%
def text_vocabulary(descriptions):
    # build vocabulary of all unique words
    vocab = set()

    for key in descriptions.keys():
        [vocab.update(d.split()) for d in descriptions[key]]

    return vocab

# %%
def save_descriptions(descriptions, filename):
    lines = list()
    for key, desc_list in descriptions.items():
        for desc in desc_list:
            lines.append(key + '\t' + desc )
    data = "\n".join(lines)
    file = open(filename,"w")
    file.write(data)
    file.close()

# %%
dataset_text = "/content/drive/MyDrive/ml/Flickr8k_text"
dataset_images = "/content/drive/MyDrive/ml/Flicker8k_Dataset"

#we prepare our text data
filename = dataset_text + "/" + "Flickr8k.token.txt"
#loading the file that contains all data
#mapping them into descriptions dictionary img to 5 captions
descriptions = all_img_captions(filename)
print("Length of descriptions =" , len(descriptions))

#cleaning the descriptions
clean_descriptions = cleaning_text(descriptions)

#building vocabulary
vocabulary = text_vocabulary(clean_descriptions)
print("Length of vocabulary = ", len(vocabulary))

#saving each description to file
save_descriptions(clean_descriptions, "/content/drive/MyDrive/ml/descriptions.txt")
# Out:
# Length of descriptions = 8092
# Length of vocabulary =  8763

# %%
def extract_features(directory):
        model = Xception( include_top=False, pooling='avg' )
        features = {}
        for img in tqdm(os.listdir(directory)):
            filename = directory + "/" + img
            image = Image.open(filename)
            image = image.resize((299,299))
            image = np.expand_dims(image, axis=0)
            #image = preprocess_input(image)
            image = image/127.5
            image = image - 1.0

            feature = model.predict(image)
            features[img] = feature
        return features

#2048 feature vector
features = extract_features(dataset_images)
dump(features, open("/content/drive/MyDrive/ml/features.p","wb"))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#   0%|          | 0/8091 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 667ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 664ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 630ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 589ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 637ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 714ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 653ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 578ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 669ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 683ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 657ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 653ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 647ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 657ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 645ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 667ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 653ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 680ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 663ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 681ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 590ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 637ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 652ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 639ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 680ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 660ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 665ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 653ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 600ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 653ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 577ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 665ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 663ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 645ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 630ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 667ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 660ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 662ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 653ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 682ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 645ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 660ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 656ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 656ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 660ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 637ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 663ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 663ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 655ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 630ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 673ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 591ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 591ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 645ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 663ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 637ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 653ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 671ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 645ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 682ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 654ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 692ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 655ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 655ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 660ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 667ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 668ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 664ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 653ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 677ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 652ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 665ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 713ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 669ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 665ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 660ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 681ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 681ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 655ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 694ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 690ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 682ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 630ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 687ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 655ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 677ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 656ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 721ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 655ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 662ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 657ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 719ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 673ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 655ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 761ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 740ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 672ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 712ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 685ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 664ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 705ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 679ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 663ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 667ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 684ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 673ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 753ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 733ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 667ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 734ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 664ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 691ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 716ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 655ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 718ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 701ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 683ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 681ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 687ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 730ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step

# %%
#load the data
def load_photos(filename):
    file = load_doc(filename)
    photos = file.split("\n")[:-1]
    photos_present = [photo for photo in photos if os.path.exists(os.path.join(dataset_images, photo))]
    return photos_present

# %%
def load_clean_descriptions(filename, photos):
    #loading clean_descriptions
    file = load_doc(filename)
    descriptions = {}
    for line in file.split("\n"):

        words = line.split()
        if len(words)<1 :
            continue

        image, image_caption = words[0], words[1:]

        if image in photos:
            if image not in descriptions:
                descriptions[image] = []
            desc = '<start> ' + " ".join(image_caption) + ' <end>'
            descriptions[image].append(desc)

    return descriptions

# %%
def load_features(photos):
    #loading all features
    all_features = load(open("features.p","rb"))
    #selecting only needed features
    features = {k:all_features[k] for k in photos}
    return features

# %%
filename = dataset_text + "/" + "Flickr_8k.trainImages.txt"

#train = loading_data(filename)
train_imgs = load_photos(filename)
train_descriptions = load_clean_descriptions("/content/drive/MyDrive/ml/descriptions.txt", train_imgs)
train_features = load_features(train_imgs)

# %%
def dict_to_list(descriptions):
    all_desc = []
    for key in descriptions.keys():
        [all_desc.append(d) for d in descriptions[key]]
    return all_desc

# %%
#creating tokenizer class
#this will vectorise text corpus
#each integer will represent token in dictionary

def create_tokenizer(descriptions):
    desc_list = dict_to_list(descriptions)
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(desc_list)
    return tokenizer

# %%
# give each word an index, and store that into tokenizer.p pickle file
tokenizer = create_tokenizer(train_descriptions)
dump(tokenizer, open('tokenizer.p', 'wb'))
vocab_size = len(tokenizer.word_index) + 1
print(vocab_size)
# Out:
# 7577

# %%
#calculate maximum length of descriptions
def max_length(descriptions):
    desc_list = dict_to_list(descriptions)
    return max(len(d.split()) for d in desc_list)

max_length = max_length(train_descriptions)
print(max_length)
# Out:
# 34

# %%
#data generator, used by model.fit()
def data_generator(descriptions, features, tokenizer, max_length):
    def generator():
        while True:
            for key, description_list in descriptions.items():
                feature = features[key][0]
                input_image, input_sequence, output_word = create_sequences(tokenizer, max_length, description_list, feature)
                for i in range(len(input_image)):
                    yield {'input_1': input_image[i], 'input_2': input_sequence[i]}, output_word[i]

    # Define the output signature for the generator
    output_signature = (
        {
            'input_1': tf.TensorSpec(shape=(2048,), dtype=tf.float32),
            'input_2': tf.TensorSpec(shape=(max_length,), dtype=tf.int32)
        },
        tf.TensorSpec(shape=(vocab_size,), dtype=tf.float32)
    )

    # Create the dataset
    dataset = tf.data.Dataset.from_generator(
        generator,
        output_signature=output_signature
    )

    return dataset.batch(32)

# %%
def create_sequences(tokenizer, max_length, desc_list, feature):
    X1, X2, y = list(), list(), list()
    # walk through each description for the image
    for desc in desc_list:
        # encode the sequence
        seq = tokenizer.texts_to_sequences([desc])[0]
        # split one sequence into multiple X,y pairs
        for i in range(1, len(seq)):
            # split into input and output pair
            in_seq, out_seq = seq[:i], seq[i]
            # pad input sequence
            in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
            # encode output sequence
            out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
            # store
            X1.append(feature)
            X2.append(in_seq)
            y.append(out_seq)
    return np.array(X1), np.array(X2), np.array(y)

# %%
#You can check the shape of the input and output for your model
dataset = data_generator(train_descriptions, features, tokenizer, max_length)
for (a, b) in dataset.take(1):
    print(a['input_1'].shape, a['input_2'].shape, b.shape)
    break
# Out:
# (32, 2048) (32, 34) (32, 7577)

# %%
from keras.utils import plot_model

# define the captioning model
def define_model(vocab_size, max_length):

    # features from the CNN model squeezed from 2048 to 256 nodes
    inputs1 = Input(shape=(2048,), name='input_1')
    fe1 = Dropout(0.5)(inputs1)
    fe2 = Dense(256, activation='relu')(fe1)

    # LSTM sequence model
    inputs2 = Input(shape=(max_length,), name='input_2')
    se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
    se2 = Dropout(0.5)(se1)
    se3 = LSTM(256)(se2)

    # Merging both models
    decoder1 = add([fe2, se3])
    decoder2 = Dense(256, activation='relu')(decoder1)
    outputs = Dense(vocab_size, activation='softmax')(decoder2)

    # tie it together [image, seq] [word]
    model = Model(inputs=[inputs1, inputs2], outputs=outputs)
    model.compile(loss='categorical_crossentropy', optimizer='adam')

    # summarize model
    print(model.summary())
    plot_model(model, to_file='model.png', show_shapes=True)

    return model

# %%
# train our model
print('Dataset: ', len(train_imgs))
print('Descriptions: train=', len(train_descriptions))
print('Photos: train=', len(train_features))
print('Vocabulary Size:', vocab_size)
print('Description Length: ', max_length)

model = define_model(vocab_size, max_length)
epochs = 2

def get_steps_per_epoch(train_descriptions):
    total_sequences = 0
    for img_captions in train_descriptions.values():
        for caption in img_captions:
            words = caption.split()
            total_sequences += len(words) - 1
    # Ensure at least 1 step, even if sequences < batch_size
    return max(1, total_sequences // 32)

# Update training loop
steps = get_steps_per_epoch(train_descriptions)

# making a directory models to save our models
import os
if not os.path.exists("models2"):
    os.mkdir("models2")
for i in range(epochs):
    dataset = data_generator(train_descriptions, train_features, tokenizer, max_length)
    model.fit(dataset, epochs=4, steps_per_epoch=steps, verbose=1)
    model.save("models2/model_" + str(i) + ".h5")
# Out:
# Dataset:  6000
# Descriptions: train= 6000
# Photos: train= 6000
# Vocabulary Size: 7577
# Description Length:  34
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_2             │ (None, 34)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_1             │ (None, 2048)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_2         │ (None, 34, 256)   │  1,939,712 │ input_2[0][0]     │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 2048)      │          0 │ input_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 34, 256)   │          0 │ embedding_2[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_2         │ (None, 34)        │          0 │ input_2[0][0]     │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │    524,544 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 256)       │    525,312 │ dropout_5[0][0],  │
# │                     │                   │            │ not_equal_2[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 256)       │          0 │ dense_6[0][0],    │
# │                     │                   │            │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 256)       │     65,792 │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 7577)      │  1,947,289 │ dense_7[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,002,649 (19.08 MB)
#  Trainable params: 5,002,649 (19.08 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/4
# 9575/9575 ━━━━━━━━━━━━━━━━━━━━ 2230s 232ms/step - loss: 4.9234
# Epoch 2/4
# 9575/9575 ━━━━━━━━━━━━━━━━━━━━ 2184s 228ms/step - loss: 3.7681
# Epoch 3/4
# 9575/9575 ━━━━━━━━━━━━━━━━━━━━ 2253s 235ms/step - loss: 3.4883
# Epoch 4/4
# 9575/9575 ━━━━━━━━━━━━━━━━━━━━ 2211s 231ms/step - loss: 3.3491
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1/4
# 9575/9575 ━━━━━━━━━━━━━━━━━━━━ 2193s 229ms/step - loss: 3.2486
# Epoch 2/4
# 9575/9575 ━━━━━━━━━━━━━━━━━━━━ 2376s 248ms/step - loss: 3.1822
# Epoch 3/4
# 9575/9575 ━━━━━━━━━━━━━━━━━━━━ 2140s 224ms/step - loss: 3.1421
# Epoch 4/4
# 9575/9575 ━━━━━━━━━━━━━━━━━━━━ 2088s 218ms/step - loss: 3.1037
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# testing

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.applications.xception import Xception
from keras.models import load_model
from pickle import load
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import argparse
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout
from tensorflow.keras.layers import add
from tensorflow.keras.models import Model

# %%
ap = argparse.ArgumentParser()
ap.add_argument('-i', '--image', required=True, help="Image Path")
args = vars(ap.parse_args())
img_path = args['image']
# Out:
# usage: colab_kernel_launcher.py [-h] -i IMAGE
# colab_kernel_launcher.py: error: the following arguments are required: -i/--image
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import argparse

# Initialize parser
ap = argparse.ArgumentParser()
ap.add_argument('-i', '--image', required=True, help="Image Path")  # Keep the required argument

# Try to parse arguments, and set a default if not found
try:
    args = vars(ap.parse_args())  # Parse command-line arguments
except SystemExit:  # Handle the SystemExit exception
    # Provide a default image path or handle it as needed
    args = {'image': '/content/drive/MyDrive/ml/Flicker8k_Dataset/1000268201_693b08cb0e.jpg'}  # Replace with your desired default
    print(f"Using default image path: {args['image']}")

# Access the image path as before
img_path = args['image']
# Out:
# Using default image path: /content/drive/MyDrive/ml/Flicker8k_Dataset/1000268201_693b08cb0e.jpg
# usage: colab_kernel_launcher.py [-h] -i IMAGE
# colab_kernel_launcher.py: error: the following arguments are required: -i/--image

# %%
def extract_features(filename, model):
        try:
            image = Image.open(filename)

        except:
            print("ERROR: Couldn't open image! Make sure the image path and extension is correct")
        image = image.resize((299,299))
        image = np.array(image)
        # for images that has 4 channels, we convert them into 3 channels
        if image.shape[2] == 4:
            image = image[..., :3]
        image = np.expand_dims(image, axis=0)
        image = image/127.5
        image = image - 1.0
        feature = model.predict(image)
        return feature

# %%
def word_for_id(integer, tokenizer):
 for word, index in tokenizer.word_index.items():
     if index == integer:
         return word
 return None

# %%
def generate_desc(model, tokenizer, photo, max_length):
    in_text = 'start'
    for i in range(max_length):
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        sequence = pad_sequences([sequence], maxlen=max_length)
        pred = model.predict([photo,sequence], verbose=0)
        pred = np.argmax(pred)
        word = word_for_id(pred, tokenizer)
        if word is None:
            break
        in_text += ' ' + word
        if word == 'end':
            break
    return in_text

# %%
from keras.utils import plot_model

def define_model(vocab_size, max_length):

    # features from the CNN model squeezed from 2048 to 256 nodes
    inputs1 = Input(shape=(2048,), name='input_1')
    fe1 = Dropout(0.5)(inputs1)
    fe2 = Dense(256, activation='relu')(fe1)

    # LSTM sequence model
    inputs2 = Input(shape=(max_length,), name='input_2')
    se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
    se2 = Dropout(0.5)(se1)
    se3 = LSTM(256)(se2)

    # Merging both models
    decoder1 = add([fe2, se3])
    decoder2 = Dense(256, activation='relu')(decoder1)
    outputs = Dense(vocab_size, activation='softmax')(decoder2)

    # tie it together [image, seq] [word]
    model = Model(inputs=[inputs1, inputs2], outputs=outputs)
    model.compile(loss='categorical_crossentropy', optimizer='adam')

    # summarize model
    print(model.summary())
    plot_model(model, to_file='model.png', show_shapes=True)

    return model

# %%
#path = 'Flicker8k_Dataset/111537222_07e56d5a30.jpg'
max_length = 32
tokenizer = load(open("tokenizer.p","rb"))
vocab_size = len(tokenizer.word_index) + 1

# First define the model architecture
model = define_model(vocab_size, max_length)
# Then load the weights
model.load_weights('models/model_9.h5')
xception_model = Xception(include_top=False, pooling="avg")

photo = extract_features(img_path, xception_model)
img = Image.open(img_path)

description = generate_desc(model, tokenizer, photo, max_length)
print("\n\n")
print(description)
plt.imshow(img)
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_2             │ (None, 32)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_1             │ (None, 2048)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_3         │ (None, 32, 256)   │  1,939,712 │ input_2[0][0]     │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 2048)      │          0 │ input_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 32, 256)   │          0 │ embedding_3[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_3         │ (None, 32)        │          0 │ input_2[0][0]     │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 256)       │    524,544 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ (None, 256)       │    525,312 │ dropout_7[0][0],  │
# │                     │                   │            │ not_equal_3[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 256)       │          0 │ dense_9[0][0],    │
# │                     │                   │            │ lstm_3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 256)       │     65,792 │ add_15[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 7577)      │  1,947,289 │ dense_10[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,002,649 (19.08 MB)
#  Trainable params: 5,002,649 (19.08 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-2570051f7b17> in <cell line: 0>()
#       7 model = define_model(vocab_size, max_length)
#       8 # Then load the weights
# ----> 9 model.load_weights('models/model_9.h5')
#      10 xception_model = Xception(include_top=False, pooling="avg")
#      11
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     562                                  fs_persist=fs_persist, fs_threshold=fs_threshold,
#     563                                  fs_page_size=fs_page_size)
# --> 564                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     565
#     566             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.11/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     236         if swmr and swmr_support:
#     237             flags |= h5f.ACC_SWMR_READ
# --> 238         fid = h5f.open(name, flags, fapl=fapl)
#     239     elif mode == 'r+':
#     240         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'models/model_9.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
#path = 'Flicker8k_Dataset/111537222_07e56d5a30.jpg'
max_length = 32
tokenizer = load(open("tokenizer.p","rb"))
vocab_size = len(tokenizer.word_index) + 1

# First define the model architecture
model = define_model(vocab_size, max_length)
# Then load the weights, ensure the path is correct, it should be "models2"
model.load_weights('models2/model_9.h5')  # Changed path to models2
xception_model = Xception(include_top=False, pooling="avg")

photo = extract_features(img_path, xception_model)
img = Image.open(img_path)

description = generate_desc(model, tokenizer, photo, max_length)
print("\n\n")
print(description)
plt.imshow(img)
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_2             │ (None, 32)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_1             │ (None, 2048)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_4         │ (None, 32, 256)   │  1,939,712 │ input_2[0][0]     │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 2048)      │          0 │ input_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 32, 256)   │          0 │ embedding_4[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_4         │ (None, 32)        │          0 │ input_2[0][0]     │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 256)       │    524,544 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_4 (LSTM)       │ (None, 256)       │    525,312 │ dropout_9[0][0],  │
# │                     │                   │            │ not_equal_4[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 256)       │          0 │ dense_12[0][0],   │
# │                     │                   │            │ lstm_4[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 256)       │     65,792 │ add_16[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 7577)      │  1,947,289 │ dense_13[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,002,649 (19.08 MB)
#  Trainable params: 5,002,649 (19.08 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-5d25319e1005> in <cell line: 0>()
#       7 model = define_model(vocab_size, max_length)
#       8 # Then load the weights, ensure the path is correct, it should be "models2"
# ----> 9 model.load_weights('models2/model_9.h5')  # Changed path to models2
#      10 xception_model = Xception(include_top=False, pooling="avg")
#      11
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     562                                  fs_persist=fs_persist, fs_threshold=fs_threshold,
#     563                                  fs_page_size=fs_page_size)
# --> 564                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     565
#     566             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.11/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     236         if swmr and swmr_support:
#     237             flags |= h5f.ACC_SWMR_READ
# --> 238         fid = h5f.open(name, flags, fapl=fapl)
#     239     elif mode == 'r+':
#     240         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'models2/model_9.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
#path = 'Flicker8k_Dataset/111537222_07e56d5a30.jpg'
max_length = 32
tokenizer = load(open("tokenizer.p","rb"))
vocab_size = len(tokenizer.word_index) + 1

# First define the model architecture
model = define_model(vocab_size, max_length)
# Then load the weights, ensure the path is correct, it should be "models2"
# The training loop only saves model_0.h5 to model_3.h5, so change to one of these
model.load_weights('models2/model_3.h5')  # Changed path to models2 and filename to model_3.h5
xception_model = Xception(include_top=False, pooling="avg")

photo = extract_features(img_path, xception_model)
img = Image.open(img_path)

description = generate_desc(model, tokenizer, photo, max_length)
print("\n\n")
print(description)
plt.imshow(img)
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_2             │ (None, 32)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_1             │ (None, 2048)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_5         │ (None, 32, 256)   │  1,939,712 │ input_2[0][0]     │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 2048)      │          0 │ input_1[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 32, 256)   │          0 │ embedding_5[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_5         │ (None, 32)        │          0 │ input_2[0][0]     │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 256)       │    524,544 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_5 (LSTM)       │ (None, 256)       │    525,312 │ dropout_11[0][0], │
# │                     │                   │            │ not_equal_5[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 256)       │          0 │ dense_15[0][0],   │
# │                     │                   │            │ lstm_5[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 256)       │     65,792 │ add_17[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 7577)      │  1,947,289 │ dense_16[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,002,649 (19.08 MB)
#  Trainable params: 5,002,649 (19.08 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-f6bc932e543b> in <cell line: 0>()
#       8 # Then load the weights, ensure the path is correct, it should be "models2"
#       9 # The training loop only saves model_0.h5 to model_3.h5, so change to one of these
# ---> 10 model.load_weights('models2/model_3.h5')  # Changed path to models2 and filename to model_3.h5
#      11 xception_model = Xception(include_top=False, pooling="avg")
#      12
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     562                                  fs_persist=fs_persist, fs_threshold=fs_threshold,
#     563                                  fs_page_size=fs_page_size)
# --> 564                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     565
#     566             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.11/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     236         if swmr and swmr_support:
#     237             flags |= h5f.ACC_SWMR_READ
# --> 238         fid = h5f.open(name, flags, fapl=fapl)
#     239     elif mode == 'r+':
#     240         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'models2/model_3.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
#path = 'Flicker8k_Dataset/111537222_07e56d5a30.jpg'
max_length = 32
tokenizer = load(open("tokenizer.p","rb"))
vocab_size = len(tokenizer.word_index) + 1

# First define the model architecture
model = define_model(vocab_size, max_length)
# Then load the weights, ensure the path is correct, it should be "models2"
# Since you ran only 2 epochs, the weights will be in either model_0.h5 or model_1.h5
model.load_weights('models2/model_1.h5')  # Changed filename to model_1.h5, use model_0.h5 if preferred
xception_model = Xception(include_top=False, pooling="avg")

photo = extract_features(img_path, xception_model)
img = Image.open(img_path)

description = generate_desc(model, tokenizer, photo, max_length)
print("\n\n")
print(description)
plt.imshow(img)
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_2             │ (None, 32)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_1             │ (None, 2048)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_6         │ (None, 32, 256)   │  1,939,712 │ input_2[0][0]     │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 2048)      │          0 │ input_1[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 32, 256)   │          0 │ embedding_6[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_6         │ (None, 32)        │          0 │ input_2[0][0]     │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 256)       │    524,544 │ dropout_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_6 (LSTM)       │ (None, 256)       │    525,312 │ dropout_13[0][0], │
# │                     │                   │            │ not_equal_6[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 256)       │          0 │ dense_18[0][0],   │
# │                     │                   │            │ lstm_6[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 256)       │     65,792 │ add_18[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 7577)      │  1,947,289 │ dense_19[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,002,649 (19.08 MB)
#  Trainable params: 5,002,649 (19.08 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#
#
#
# start man in red shirt and hat is standing in front of the street end
